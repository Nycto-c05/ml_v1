# %% [markdown]
# Implement K-Nearest Neighbours’ algorithm on Social network ad dataset. Compute confusion matrix, accuracy, error rate, precision and recall on the given dataset. Dataset link:https://www.kaggle.com/datasets/ rakeshrau/social-network-ads

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv("/content/3. Classification_Analysis(K-nearest)_Social_Network_Ads.csv")
data
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
le = LabelEncoder()
data["Gender"] = le.fit_transform(data["Gender"])
df = data.drop(columns = ["User ID"])
df
# Out:
#      Gender  Age  EstimatedSalary  Purchased
# 0         1   19            19000          0
# 1         1   35            20000          0
# 2         0   26            43000          0
# 3         0   27            57000          0
# 4         1   19            76000          0
# ..      ...  ...              ...        ...
# 395       0   46            41000          1
# 396       1   51            23000          1
# 397       0   50            20000          1
# 398       1   36            33000          0
# 399       0   49            36000          1
#
# [400 rows x 4 columns]

# %%
X = df.drop(columns=["Purchased"])
X
# Out:
#      Gender  Age  EstimatedSalary
# 0         1   19            19000
# 1         1   35            20000
# 2         0   26            43000
# 3         0   27            57000
# 4         1   19            76000
# ..      ...  ...              ...
# 395       0   46            41000
# 396       1   51            23000
# 397       0   50            20000
# 398       1   36            33000
# 399       0   49            36000
#
# [400 rows x 3 columns]

# %%
Y = df["Purchased"]
Y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state = 42)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
# implementing K nearest neighbours
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 5)
knn.fit(x_train, y_train)

y_pred = knn.predict(x_test)

# %%
# confusion matrix, accuracy, error rate, precision and recall
from sklearn.metrics import confusion_matrix, accuracy_score
cmatrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
cmatrix
# Out:
# array([[48,  4],
#        [ 2, 26]])

# %%
accuracy
# Out:
# 0.925

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score
# Calculate precision
precision = precision_score(y_test, y_pred)
print("Precision: " , precision)

# Calculate recall
recall = recall_score(y_test, y_pred)
print("Recall: ", recall)

# Calculate error rate
error_rate = 1 - accuracy
print("Error Rate: ", error_rate)
# Out:
# Precision:  0.8666666666666667
# Recall:  0.9285714285714286
# Error Rate:  0.07499999999999996
